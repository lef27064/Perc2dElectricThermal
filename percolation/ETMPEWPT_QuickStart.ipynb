# %% [markdown]
# # ETMPEWPT: 2D Continuum Percolation & Transport Properties Simulation
# This notebook demonstrates how to clone, compile, and execute **ETMPEWPT** in a cloud Linux environment, and visualize the generated microstructures and output reports.
#
# * **Repository:** [GitHub - Perc2dElectricThermal](https://github.com/lef27064/Perc2dElectricThermal)
# * **Author:** Eleftherios Lambrou

# %%
import os
import shutil

# 1. move to /content
# %cd /content

# 2. Delete all files except sample_data of Colab
for item in os.listdir('/content'):
    if item != 'sample_data':
        path = os.path.join('/content', item)
        if os.path.isdir(path):
            shutil.rmtree(path)
        else:
            os.remove(path)

print("Work space cleaned!")
# Out:
# /content
# Ο χώρος εργασίας καθαρίστηκε πλήρως!

# %%
# 1. Clone το repository
# !git clone https://github.com/lef27064/Perc2dElectricThermal.git

# 2. Change directory to roor directory od ferository
# %cd Perc2dElectricThermal/percolation

# 3. control files wich is live inside
# !ls -la
# Out:
# Cloning into 'Perc2dElectricThermal'...
# remote: Enumerating objects: 7973, done.
# remote: Counting objects: 100% (6842/6842), done.
# remote: Compressing objects: 100% (283/283), done.
# remote: Total 7973 (delta 6686), reused 6689 (delta 6552), pack-reused 1131 (from 1)
# Receiving objects: 100% (7973/7973), 23.96 MiB | 19.71 MiB/s, done.
# Resolving deltas: 100% (7488/7488), done.
# /content/Perc2dElectricThermal/percolation
# total 680
# drwxr-xr-x 4 root root  4096 Sep 21 18:25 .
# drwxr-xr-x 6 root root  4096 Sep 21 18:25 ..
# -rw-r--r-- 1 root root 31606 Sep 21 18:25 BatchMonteCarlo.cpp
# -rw-r--r-- 1 root root  2591 Sep 21 18:25 BatchMonteCarlo.h
# -rw-r--r-- 1 root root  3238 Sep 21 18:25 cluster.cpp
# -rw-r--r-- 1 root root  6139 Sep 21 18:25 cluster.h
# -rw-r--r-- 1 root root  4058 Sep 21 18:25 Continuum-Percolation.cbp
# -rw-r--r-- 1 root root  3169 Sep 21 18:25 Continuum-Percolation.depend
# -rw-r--r-- 1 root root   921 Sep 21 18:25 Continuum-Percolation.layout
# -rw-r--r-- 1 root root  6894 Sep 21 18:25 Continuum-Percolation.vcxproj
# -rw-r--r-- 1 root root  3776 Sep 21 18:25 Continuum-Percolation.vcxproj.linux
# -rw-r--r-- 1 root root  4286 Sep 21 18:25 Dinic.cpp
# -rw-r--r-- 1 root root  7621 Sep 21 18:25 Dinic_omp.cpp
# -rw-r--r-- 1 root root   896 Sep 21 18:25 Dinic_omp.h
# -rw-r--r-- 1 root root 26469 Sep 21 18:25 dirent.h
# -rw-r--r-- 1 root root  3734 Sep 21 18:25 Edmonds_karp.cpp
# -rw-r--r-- 1 root root   791 Sep 21 18:25 Edmonds_karp.h
# drwxr-xr-x 3 root root  4096 Sep 21 18:25 example
# -rw-r--r-- 1 root root 31944 Sep 21 18:25 FD2DEL.cpp
# -rw-r--r-- 1 root root  9890 Sep 21 18:25 FD2DEL.h
# -rw-r--r-- 1 root root  8477 Sep 21 18:25 general.cpp
# -rw-r--r-- 1 root root  6148 Sep 21 18:25 general.h
# -rw-r--r-- 1 root root 57169 Sep 21 18:25 Grid.bak.cpp
# -rw-r--r-- 1 root root 62520 Sep 21 18:25 Grid.cpp
# -rw-r--r-- 1 root root 14791 Sep 21 18:25 Grid.h
# -rw-r--r-- 1 root root 17793 Sep 21 18:25 image.cpp
# -rw-r--r-- 1 root root  6314 Sep 21 18:25 image.h
# drwxr-xr-x 2 root root  4096 Sep 21 18:25 inputs
# -rw-r--r-- 1 root root  4269 Sep 21 18:25 main.cpp
# -rw-r--r-- 1 root root   326 Sep 21 18:25 mods.txt
# -rw-r--r-- 1 root root  4253 Sep 21 18:25 Percolation.cbp
# -rw-r--r-- 1 root root   770 Sep 21 18:25 Percolation.common.settings
# -rw-r--r-- 1 root root  5457 Sep 21 18:25 Percolation.depend
# -rw-r--r-- 1 root root   182 Sep 21 18:25 Percolation.layout
# -rw-r--r-- 1 root root  9232 Sep 21 18:25 Percolation.vcxproj
# -rw-r--r-- 1 root root  3287 Sep 21 18:25 Percolation.vcxproj.filters
# -rw-r--r-- 1 root root  9135 Sep 21 18:25 Settings.cpp
# -rw-r--r-- 1 root root  3917 Sep 21 18:25 Settings.h
# -rw-r--r-- 1 root root   149 Sep 21 18:25 settings.txt
# -rw-r--r-- 1 root root 97451 Sep 21 18:25 ShapeGenerator.cpp
# -rw-r--r-- 1 root root 22839 Sep 21 18:25 ShapeGenerator.h
# -rw-r--r-- 1 root root 18143 Sep 21 18:25 Shapes.cpp
# -rw-r--r-- 1 root root  9128 Sep 21 18:25 Shapes.h
# -rw-r--r-- 1 root root  5463 Sep 21 18:25 SimplePathFinder.cpp
# -rw-r--r-- 1 root root  1036 Sep 21 18:25 SimplePathFinder.h
# -rw-r--r-- 1 root root 71234 Sep 21 18:25 stb_image_write.h

# %%
# Μεταγλώττιση C++17 με OpenMP
# !g++ main.cpp cluster.cpp BatchMonteCarlo.cpp Settings.cpp Grid.cpp Shapes.cpp image.cpp FD2DEL.cpp ShapeGenerator.cpp general.cpp -o ETMPEWPT -fopenmp -std=c++17 -O3

# Επαλήθευση ότι δημιουργήθηκε το εκτελέσιμο ETMPEWPT
# !ls -lh ETMPEWPT
# Out:
# BatchMonteCarlo.cpp: In constructor ‘BatchMonteCarlo::BatchMonteCarlo()’:
# BatchMonteCarlo.cpp:47:31: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    47 |         settings.readFromFile("settings.txt");
#       |                               ^~~~~~~~~~~~~~
# BatchMonteCarlo.cpp: In constructor ‘BatchMonteCarlo::BatchMonteCarlo(std::string)’:
# BatchMonteCarlo.cpp:63:31: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    63 |         settings.readFromFile("settings.txt");
#       |                               ^~~~~~~~~~~~~~
# ShapeGenerator.cpp: In member function ‘void ShapeGenerator::monteCarlo()’:
# ShapeGenerator.cpp:843:34: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#   843 |                 char* fileName = "cluster.bmp"; // Filename for cluster image
#       |                                  ^~~~~~~~~~~~~
# -rwxr-xr-x 1 root root 398K Sep 21 09:49 ETMPEWPT

# %%
import os

# 1. Βεβαιωνόμαστε ότι είμαστε στον φάκελο percolation
if os.path.basename(os.getcwd()) != 'percolation':
    # %cd /content/Perc2dElectricThermal/percolation

# 2. Δημιουργία των απαραίτητων φακέλων
os.makedirs("inputs", exist_ok=True)
os.makedirs("outputs", exist_ok=True)

# 3. Δημιουργία του settings.txt
settings_content = """#Total Iterations to Run :
5
#Save image file(s) :
TRUE
#Save random image(s) :
1
#Save image(s) for specific iteration(s) :
FALSE
#Iterations to save :
1
#Current directory :
"./outputs/"
"""

with open("settings.txt", "w") as f:
    f.write(settings_content)

# 4. Δημιουργία ενός δοκιμαστικού input αρχείου (inputs/example_2d.txt)
input_content = """#name
example_run
#total component
3
#components % weights
0.4 0.3 0.3
#Components type Geometry : RECTANGLE = 0, SLOPEDRECTANGLE = 1, ELLIPSE = 3, NONE = 4
4 3 1
#SizeType CONSTANT = 0, VARIABLE = 1, NONE = 3
3 0 0
#Special Weights
1.6532 1.3279 1.342
#Dimension X
10.0e-09 10.0e-09 1.0e-09
#Dimension Y
10.0e-09 10.0e-09 10.0e-09
#hoops
0.5e-09 0.5e-09 0.5e-09
#Electric Conductivities
1.e-16 1.0 0.5
#Thermal Conductivities
1.e-16 1.0 0.5
#Young Modulus
1.e+5 1.e+10 0.5e+9
#Poisson Ratio
0.3 0.32 0.31
#width - height
500 500
#iterations
5
#pixels per min Sphere
101
#Swiss chesse case TRUE or FALSE
FALSE
# CALC ELECTRIC CONDUCTIVITY
TRUE
# CALC ELECTRIC CONDUCTIVITY WITH FINITE DIFFERENCES
FALSE
# CALCULATE STATISTICS
FALSE
"""

with open("inputs/example_2d.txt", "w") as f:
    f.write(input_content)

print("Τα αρχεία settings.txt και inputs/example_2d.txt δημιουργήθηκαν επιτυχώς!")

# 5. Εκτέλεση του ETMPEWPT
# !./ETMPEWPT
# Out:
# Τα αρχεία settings.txt και inputs/example_2d.txt δημιουργήθηκαν επιτυχώς!
# ----------------------------------------------------------------------------------------------------
# Electric,Thermal, Mechanical Properties Estimation With Percolation Theory (ETMPEWPT) (2D version)
# Version 2.0 Percolation, Cluster Analysis, Electric - Thermal - Mechanical properties
# Last update: 1/7/2024
# Author:Eleftherios Lamprou
# Licence:This program is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License.
# Developed during PhD Thesis (2017-2024)
# ----------------------------------------------------------------------------------------------------
# Start at Mon Sep 21 09:49:25 2026
#
# --------------------------------------------------------------------------------------------------------------
# Files in working directory inputs
# inputs/test.txt
# inputs/example_2d.txt
#
# --------------------------------------------------------------------------------------------------------------
#
# Input File: /content/Perc2dElectricThermal/percolation/inputs/test.txt
#
# --------------------------------------------------------------------------------------------------------------
# Solve from % Weights to % Area
# Component            %Area          %Weight        Estimation Error
#             0         0.35         0.35                        0
#             1         0.65         0.65                        0
# Total error e=0 - Total iterations= 1
# ----------------------------------------------------------------------------------------------------
# Running for 2,000x2,000 Grid
# ----------------------------------------------------------------------------------------------------
# Pixels Per minimum Size (ppms)=101
# Minimum Size 1e-08
# Factor [ppms/ minimumSize]1.01e+10
#
# --------------------------------------------------Case      1 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         539                  0.65076                  0.65      -0.00075975
#          0               Matrix         N/A                  0.34924                  0.35       0.00075975
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:0%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 490.193
# Correlation length=234,472
#
# --------------------------------------------------Case      2 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         542                 0.650493                  0.65       -0.0004935
#          0               Matrix         N/A                 0.349507                  0.35        0.0004935
# mean Paths per RVE=70
# mean RVE electric resistance=59.9913
# mean RVE Thermal resistance=59.9913
# mean RVE Young Modulus=9.70119e+07
# mean RVE Poissons Ratio=0.293831
# mean RVE Shear Modoulus=3.74902e+07
# RSE IS percolate
# RSE's Percolation Probability:50%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 346.548
# Correlation length=187,934
#
# --------------------------------------------------Case      3 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         538                 0.650705                  0.65       -0.0007045
#          0               Matrix         N/A                 0.349295                  0.35        0.0007045
# mean Paths per RVE=82
# mean RVE electric resistance=46.5323
# mean RVE Thermal resistance=46.5323
# mean RVE Young Modulus=9.76074e+07
# mean RVE Poissons Ratio=0.283522
# mean RVE Shear Modoulus=3.80233e+07
# RSE IS percolate
# RSE's Percolation Probability:66.6667%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 588.698
# Correlation length=175,619
#
# --------------------------------------------------Case      4 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         520                 0.650752                  0.65      -0.00075175
#          0               Matrix         N/A                 0.349248                  0.35       0.00075175
# mean Paths per RVE=24
# mean RVE electric resistance=196.332
# mean RVE Thermal resistance=196.332
# mean RVE Young Modulus=9.87622e+07
# mean RVE Poissons Ratio=0.29929
# mean RVE Shear Modoulus=3.80062e+07
# RSE IS percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 660.134
# Correlation length=204,177
#
# --------------------------------------------------Case      5 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         530                 0.650393                  0.65        -0.000393
#          0               Matrix         N/A                 0.349607                  0.35         0.000393
# mean Paths per RVE=46
# mean RVE electric resistance=85.538
# mean RVE Thermal resistance=85.538
# mean RVE Young Modulus=9.79395e+07
# mean RVE Poissons Ratio=0.295199
# mean RVE Shear Modoulus=3.78087e+07
# RSE IS percolate
# RSE's Percolation Probability:80%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 377.463
# Correlation length=186,743
#
# --------------------------------------------------Case      6 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         543                 0.650073                  0.65        -7.35e-05
#          0               Matrix         N/A                 0.349927                  0.35         7.35e-05
# mean Paths per RVE=77
# mean RVE electric resistance=56.2389
# mean RVE Thermal resistance=56.2389
# mean RVE Young Modulus=9.62562e+07
# mean RVE Poissons Ratio=0.296407
# mean RVE Shear Modoulus=3.71242e+07
# RSE IS percolate
# RSE's Percolation Probability:83.3333%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 538.788
# Correlation length=208,952
#
# --------------------------------------------------Case      7 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         536                 0.650134                  0.65      -0.00013375
#          0               Matrix         N/A                 0.349866                  0.35       0.00013375
# mean Paths per RVE=59
# mean RVE electric resistance=80.8235
# mean RVE Thermal resistance=80.8235
# mean RVE Young Modulus=9.69171e+07
# mean RVE Poissons Ratio=0.298992
# mean RVE Shear Modoulus=3.73047e+07
# RSE IS percolate
# RSE's Percolation Probability:85.7143%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 503.541
# Correlation length=206,518
#
# --------------------------------------------------Case      8 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         542                 0.650708                  0.65      -0.00070775
#          0               Matrix         N/A                 0.349292                  0.35       0.00070775
# mean Paths per RVE=1
# mean RVE electric resistance=2,500.28
# mean RVE Thermal resistance=2,500.28
# mean RVE Young Modulus=9.98717e+07
# mean RVE Poissons Ratio=0.299963
# mean RVE Shear Modoulus=3.84133e+07
# RSE IS percolate
# RSE's Percolation Probability:87.5%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 534.705
# Correlation length=220,196
#
# --------------------------------------------------Case      9 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         531                 0.650249                  0.65        -0.000249
#          0               Matrix         N/A                 0.349751                  0.35         0.000249
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:77.7778%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 734.907
# Correlation length=416,204
#
# --------------------------------------------------Case     10 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         540                 0.650673                  0.65        -0.000673
#          0               Matrix         N/A                 0.349327                  0.35         0.000673
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:70%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 290.392
# Correlation length=408,328
#
# --------------------------------------------------Case     11 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         549                 0.650038                  0.65       -3.825e-05
#          0               Matrix         N/A                 0.349962                  0.35        3.825e-05
# mean Paths per RVE=45
# mean RVE electric resistance=116.176
# mean RVE Thermal resistance=116.176
# mean RVE Young Modulus=9.76202e+07
# mean RVE Poissons Ratio=0.299627
# mean RVE Shear Modoulus=3.7557e+07
# RSE IS percolate
# RSE's Percolation Probability:72.7273%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 485.112
# Correlation length=398,643
#
# --------------------------------------------------Case     12 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         542                 0.650034                  0.65        -3.35e-05
#          0               Matrix         N/A                 0.349966                  0.35         3.35e-05
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:66.6667%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 717.347
# Correlation length=434,298
#
# --------------------------------------------------Case     13 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         536                 0.650253                  0.65        -0.000253
#          0               Matrix         N/A                 0.349747                  0.35         0.000253
# mean Paths per RVE=24
# mean RVE electric resistance=206.717
# mean RVE Thermal resistance=206.717
# mean RVE Young Modulus=9.86715e+07
# mean RVE Poissons Ratio=0.299698
# mean RVE Shear Modoulus=3.79594e+07
# RSE IS percolate
# RSE's Percolation Probability:69.2308%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 558.553
# Correlation length=424,982
#
# --------------------------------------------------Case     14 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         554                 0.651204                  0.65      -0.00120425
#          0               Matrix         N/A                 0.348796                  0.35       0.00120425
# mean Paths per RVE=90
# mean RVE electric resistance=45.8858
# mean RVE Thermal resistance=45.8858
# mean RVE Young Modulus=9.63784e+07
# mean RVE Poissons Ratio=0.29062
# mean RVE Shear Modoulus=3.7338e+07
# RSE IS percolate
# RSE's Percolation Probability:71.4286%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 444.829
# Correlation length=420,761
#
# --------------------------------------------------Case     15 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         550                 0.650834                  0.65       -0.0008345
#          0               Matrix         N/A                 0.349166                  0.35        0.0008345
# mean Paths per RVE=2
# mean RVE electric resistance=1,361.56
# mean RVE Thermal resistance=1,361.56
# mean RVE Young Modulus=9.97959e+07
# mean RVE Poissons Ratio=0.299889
# mean RVE Shear Modoulus=3.83863e+07
# RSE IS percolate
# RSE's Percolation Probability:73.3333%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 512.207
# Correlation length=415,706
#
# --------------------------------------------------Case     16 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         557                 0.651276                  0.65       -0.0012755
#          0               Matrix         N/A                 0.348724                  0.35        0.0012755
# mean Paths per RVE=88
# mean RVE electric resistance=47.9635
# mean RVE Thermal resistance=47.9635
# mean RVE Young Modulus=9.58838e+07
# mean RVE Poissons Ratio=0.294621
# mean RVE Shear Modoulus=3.70316e+07
# RSE IS percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 608.552
# Correlation length=412,796
#
# --------------------------------------------------Case     17 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         532                 0.651189                  0.65      -0.00118925
#          0               Matrix         N/A                 0.348811                  0.35       0.00118925
# mean Paths per RVE=1
# mean RVE electric resistance=1,781.8
# mean RVE Thermal resistance=1,781.8
# mean RVE Young Modulus=9.98593e+07
# mean RVE Poissons Ratio=0.299844
# mean RVE Shear Modoulus=3.8412e+07
# RSE IS percolate
# RSE's Percolation Probability:76.4706%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 587.297
# Correlation length=406,140
#
# --------------------------------------------------Case     18 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         542                 0.650302                  0.65      -0.00030225
#          0               Matrix         N/A                 0.349698                  0.35       0.00030225
# mean Paths per RVE=50
# mean RVE electric resistance=99.5994
# mean RVE Thermal resistance=99.5994
# mean RVE Young Modulus=9.73789e+07
# mean RVE Poissons Ratio=0.299367
# mean RVE Shear Modoulus=3.74717e+07
# RSE IS percolate
# RSE's Percolation Probability:77.7778%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 444.615
# Correlation length=404,488
#
# --------------------------------------------------Case     19 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         555                 0.650914                  0.65       -0.0009145
#          0               Matrix         N/A                 0.349086                  0.35        0.0009145
# mean Paths per RVE=2
# mean RVE electric resistance=1,665.72
# mean RVE Thermal resistance=1,665.72
# mean RVE Young Modulus=9.98694e+07
# mean RVE Poissons Ratio=0.299734
# mean RVE Shear Modoulus=3.84192e+07
# RSE IS percolate
# RSE's Percolation Probability:78.9474%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 547.813
# Correlation length=400,214
#
# --------------------------------------------------Case     20 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         547                 0.651373                  0.65        -0.001373
#          0               Matrix         N/A                 0.348627                  0.35         0.001373
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 363.854
# Correlation length=390,962
#
# --------------------------------------------------Case     21 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         551                 0.650866                  0.65      -0.00086575
#          0               Matrix         N/A                 0.349134                  0.35       0.00086575
# mean Paths per RVE=24
# mean RVE electric resistance=193.433
# mean RVE Thermal resistance=193.433
# mean RVE Young Modulus=9.88076e+07
# mean RVE Poissons Ratio=0.299042
# mean RVE Shear Modoulus=3.80309e+07
# RSE IS percolate
# RSE's Percolation Probability:76.1905%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 460.081
# Correlation length=384,690
#
# --------------------------------------------------Case     22 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         539                 0.651945                  0.65       -0.0019445
#          0               Matrix         N/A                 0.348055                  0.35        0.0019445
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:72.7273%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 410.907
# Correlation length=375,778
#
# --------------------------------------------------Case     23 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         544                 0.650196                  0.65      -0.00019575
#          0               Matrix         N/A                 0.349804                  0.35       0.00019575
# mean Paths per RVE=42
# mean RVE electric resistance=105.311
# mean RVE Thermal resistance=105.311
# mean RVE Young Modulus=9.81044e+07
# mean RVE Poissons Ratio=0.297215
# mean RVE Shear Modoulus=3.78134e+07
# RSE IS percolate
# RSE's Percolation Probability:73.913%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 461
# Correlation length=369,500
#
# --------------------------------------------------Case     24 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         511                 0.651409                  0.65       -0.0014095
#          0               Matrix         N/A                 0.348591                  0.35        0.0014095
# mean Paths per RVE=5
# mean RVE electric resistance=713.996
# mean RVE Thermal resistance=713.996
# mean RVE Young Modulus=9.96313e+07
# mean RVE Poissons Ratio=0.299789
# mean RVE Shear Modoulus=3.8326e+07
# RSE IS percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 605.031
# Correlation length=366,713
#
# --------------------------------------------------Case     25 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         548                 0.650409                  0.65       -0.0004095
#          0               Matrix         N/A                 0.349591                  0.35        0.0004095
# mean Paths per RVE=20
# mean RVE electric resistance=240.832
# mean RVE Thermal resistance=240.832
# mean RVE Young Modulus=9.88977e+07
# mean RVE Poissons Ratio=0.299643
# mean RVE Shear Modoulus=3.8048e+07
# RSE IS percolate
# RSE's Percolation Probability:76%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 446.014
# Correlation length=363,796
#
# --------------------------------------------------Case     26 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         525                 0.650185                  0.65      -0.00018475
#          0               Matrix         N/A                 0.349815                  0.35       0.00018475
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:73.0769%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 627.563
# Correlation length=364,636
#
# --------------------------------------------------Case     27 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         522                 0.650023                  0.65       -2.275e-05
#          0               Matrix         N/A                 0.349977                  0.35        2.275e-05
# mean Paths per RVE=10
# mean RVE electric resistance=503.221
# mean RVE Thermal resistance=503.221
# mean RVE Young Modulus=9.94415e+07
# mean RVE Poissons Ratio=0.299831
# mean RVE Shear Modoulus=3.82517e+07
# RSE IS percolate
# RSE's Percolation Probability:74.0741%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 494.319
# Correlation length=363,595
#
# --------------------------------------------------Case     28 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         540                 0.651145                  0.65      -0.00114525
#          0               Matrix         N/A                 0.348855                  0.35       0.00114525
# mean Paths per RVE=63
# mean RVE electric resistance=72.0633
# mean RVE Thermal resistance=72.0633
# mean RVE Young Modulus=9.68326e+07
# mean RVE Poissons Ratio=0.29805
# mean RVE Shear Modoulus=3.72992e+07
# RSE IS percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 307.806
# Correlation length=362,194
#
# --------------------------------------------------Case     29 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         559                 0.650555                  0.65       -0.0005545
#          0               Matrix         N/A                 0.349445                  0.35        0.0005545
# mean Paths per RVE=6
# mean RVE electric resistance=762.681
# mean RVE Thermal resistance=762.681
# mean RVE Young Modulus=9.96142e+07
# mean RVE Poissons Ratio=0.299897
# mean RVE Shear Modoulus=3.83162e+07
# RSE IS percolate
# RSE's Percolation Probability:75.8621%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 467.488
# Correlation length=356,147
#
# --------------------------------------------------Case     30 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         518                 0.650531                  0.65       -0.0005305
#          0               Matrix         N/A                 0.349469                  0.35        0.0005305
# mean Paths per RVE=13
# mean RVE electric resistance=328.824
# mean RVE Thermal resistance=328.824
# mean RVE Young Modulus=9.93637e+07
# mean RVE Poissons Ratio=0.299005
# mean RVE Shear Modoulus=3.82461e+07
# RSE IS percolate
# RSE's Percolation Probability:76.6667%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 595.844
# Correlation length=355,093
#
# --------------------------------------------------Case     31 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         546                 0.650847                  0.65      -0.00084675
#          0               Matrix         N/A                 0.349153                  0.35       0.00084675
# mean Paths per RVE=1
# mean RVE electric resistance=2,307.01
# mean RVE Thermal resistance=2,307.01
# mean RVE Young Modulus=9.98796e+07
# mean RVE Poissons Ratio=0.299916
# mean RVE Shear Modoulus=3.84177e+07
# RSE IS percolate
# RSE's Percolation Probability:77.4194%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 609.93
# Correlation length=350,680
#
# --------------------------------------------------Case     32 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         518                  0.65078                  0.65      -0.00077975
#          0               Matrix         N/A                  0.34922                  0.35       0.00077975
# mean Paths per RVE=48
# mean RVE electric resistance=96.5064
# mean RVE Thermal resistance=96.5064
# mean RVE Young Modulus=9.75799e+07
# mean RVE Poissons Ratio=0.298597
# mean RVE Shear Modoulus=3.75713e+07
# RSE IS percolate
# RSE's Percolation Probability:78.125%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 548.583
# Correlation length=348,492
#
# --------------------------------------------------Case     33 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         524                  0.65008                  0.65       -8.025e-05
#          0               Matrix         N/A                  0.34992                  0.35        8.025e-05
# mean Paths per RVE=6
# mean RVE electric resistance=636.342
# mean RVE Thermal resistance=636.342
# mean RVE Young Modulus=9.96694e+07
# mean RVE Poissons Ratio=0.299402
# mean RVE Shear Modoulus=3.8352e+07
# RSE IS percolate
# RSE's Percolation Probability:78.7879%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 505.749
# Correlation length=344,319
#
# --------------------------------------------------Case     34 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         545                  0.65066                  0.65       -0.0006605
#          0               Matrix         N/A                  0.34934                  0.35        0.0006605
# mean Paths per RVE=1
# mean RVE electric resistance=2,277.66
# mean RVE Thermal resistance=2,277.66
# mean RVE Young Modulus=9.99148e+07
# mean RVE Poissons Ratio=0.299724
# mean RVE Shear Modoulus=3.84369e+07
# RSE IS percolate
# RSE's Percolation Probability:79.4118%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 536.437
# Correlation length=341,550
#
# --------------------------------------------------Case     35 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         516                 0.650405                  0.65        -0.000405
#          0               Matrix         N/A                 0.349595                  0.35         0.000405
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:77.1429%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 500.397
# Correlation length=338,447
#
# --------------------------------------------------Case     36 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         554                 0.651073                  0.65       -0.0010725
#          0               Matrix         N/A                 0.348927                  0.35        0.0010725
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 653.675
# Correlation length=347,489
#
# --------------------------------------------------Case     37 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         534                 0.650509                  0.65       -0.0005095
#          0               Matrix         N/A                 0.349491                  0.35        0.0005095
# mean Paths per RVE=24
# mean RVE electric resistance=206.668
# mean RVE Thermal resistance=206.668
# mean RVE Young Modulus=9.8705e+07
# mean RVE Poissons Ratio=0.299636
# mean RVE Shear Modoulus=3.79741e+07
# RSE IS percolate
# RSE's Percolation Probability:75.6757%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 510.953
# Correlation length=345,080
#
# --------------------------------------------------Case     38 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         524                 0.650476                  0.65      -0.00047625
#          0               Matrix         N/A                 0.349524                  0.35       0.00047625
# mean Paths per RVE=38
# mean RVE electric resistance=111.763
# mean RVE Thermal resistance=111.763
# mean RVE Young Modulus=9.83256e+07
# mean RVE Poissons Ratio=0.296723
# mean RVE Shear Modoulus=3.79131e+07
# RSE IS percolate
# RSE's Percolation Probability:76.3158%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 530.985
# Correlation length=342,172
#
# --------------------------------------------------Case     39 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         531                 0.650728                  0.65      -0.00072775
#          0               Matrix         N/A                 0.349272                  0.35       0.00072775
# mean Paths per RVE=56
# mean RVE electric resistance=73.4188
# mean RVE Thermal resistance=73.4188
# mean RVE Young Modulus=9.7812e+07
# mean RVE Poissons Ratio=0.293277
# mean RVE Shear Modoulus=3.78156e+07
# RSE IS percolate
# RSE's Percolation Probability:76.9231%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 547.34
# Correlation length=341,897
#
# --------------------------------------------------Case     40 of     40--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses         512                 0.650185                  0.65      -0.00018475
#          0               Matrix         N/A                 0.349815                  0.35       0.00018475
# mean Paths per RVE=0
# mean RVE electric resistance=0
# mean RVE Thermal resistance=0
# mean RVE Young Modulus=1e+08
# mean RVE Poissons Ratio=0.3
# mean RVE Shear Modoulus=3.84615e+07
# RSE Is NOT percolate
# RSE's Percolation Probability:75%
# ----------------------------------------------------------------------------------------------------
# Calculate Statistics.. Mark Clusters,Max Radius = 410.767
# Correlation length=340,055
# ------------------------------------------ Results(RSE)  ------------------------------------------
# Mean Percolation  =0.75
# Mean Process Time  =0.157403
# Mean SetUp Time  =1.00824
# Mean Paths per RSE=25.45
# Mean Paths Length per RSE=4,757.11
# Mean path Width =1.09427
# Mean Special Electric Conductivity =0.00585421
# Mean Special Thermal Conductivity =0.00585421
# Mean Young Modulus =9.87782e+07
# Mean Shear Modulus =3.80394e+07
# Mean Poisson Ratio= 0.298366
# ----------------------------------------------------------------------------------------------------
#
# Running 2,000x2,000 grid 40 times
# Total time =50.8192sec or 0.846986min or 0.0141164h
# Finish at Mon Sep 21 09:50:02 2026
# Input File: /content/Perc2dElectricThermal/percolation/inputs/example_2d.txt
#
# --------------------------------------------------------------------------------------------------------------
# Solve from % Weights to % Area
# Component            %Area          %Weight        Estimation Error
#             0     0.349938          0.4                        0
#             1     0.326748          0.3                        0
#             2     0.323315          0.3                        0
# Total error e=0 - Total iterations= 2
# ----------------------------------------------------------------------------------------------------
# Running for 500x500 Grid
# ----------------------------------------------------------------------------------------------------
# Pixels Per minimum Size (ppms)=101
# Minimum Size 1e-08
# Factor [ppms/ minimumSize]1.01e+10
#
# --------------------------------------------------Case      1 of      5--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses          14                 0.346332              0.326748       -0.0195845
#          2    Sloped Rectangles         183                  0.32388              0.323315     -0.000565496
#          0               Matrix         N/A                 0.329788              0.349938          0.02015
# mean Paths per RVE=68
# mean RVE electric resistance=20.5468
# mean RVE Thermal resistance=20.5468
# mean RVE Young Modulus=784,318
# mean RVE Poissons Ratio=-0.151098
# mean RVE Shear Modoulus=461,961
# RSE IS percolate
# RSE's Percolation Probability:100%
#
# --------------------------------------------------Case      2 of      5--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses          13                 0.334084              0.326748      -0.00733646
#          2    Sloped Rectangles         182                 0.324636              0.323315       -0.0013215
#          0               Matrix         N/A                  0.34128              0.349938       0.00865795
# mean Paths per RVE=131
# mean RVE electric resistance=9.50236
# mean RVE Thermal resistance=9.50236
# mean RVE Young Modulus=4.11732e+06
# mean RVE Poissons Ratio=-0.140204
# mean RVE Shear Modoulus=2.39436e+06
# RSE IS percolate
# RSE's Percolation Probability:100%
#
# --------------------------------------------------Case      3 of      5--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses          12                 0.333568              0.326748      -0.00682046
#          2    Sloped Rectangles         176                 0.324764              0.323315       -0.0014495
#          0               Matrix         N/A                 0.341668              0.349938       0.00826995
# mean Paths per RVE=96
# mean RVE electric resistance=15.4193
# mean RVE Thermal resistance=15.4193
# mean RVE Young Modulus=858,740
# mean RVE Poissons Ratio=-0.156755
# mean RVE Shear Modoulus=509,188
# RSE IS percolate
# RSE's Percolation Probability:100%
#
# --------------------------------------------------Case      4 of      5--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses          16                  0.35746              0.326748       -0.0307125
#          2    Sloped Rectangles         170                 0.323816              0.323315     -0.000501496
#          0               Matrix         N/A                 0.318724              0.349938         0.031214
# mean Paths per RVE=114
# mean RVE electric resistance=12.3781
# mean RVE Thermal resistance=12.3781
# mean RVE Young Modulus=1.4392e+06
# mean RVE Poissons Ratio=-0.157191
# mean RVE Shear Modoulus=853,811
# RSE IS percolate
# RSE's Percolation Probability:100%
#
# --------------------------------------------------Case      5 of      5--------------------------------------------------
# Component  |     Particle Type      | Total Praticles | Real Area in Lattice % | Goal Area % |  Error %
#          1             Ellipses          14                  0.35006              0.326748       -0.0233125
#          2    Sloped Rectangles         191                 0.324796              0.323315       -0.0014815
#          0               Matrix         N/A                 0.325144              0.349938         0.024794
# mean Paths per RVE=78
# mean RVE electric resistance=19.5854
# mean RVE Thermal resistance=19.5854
# mean RVE Young Modulus=648,255
# mean RVE Poissons Ratio=-0.15032
# mean RVE Shear Modoulus=381,470
# RSE IS percolate
# RSE's Percolation Probability:100%
# ------------------------------------------ Results(RSE)  ------------------------------------------
# Mean Percolation  =1
# Mean Process Time  =0.0634592
# Mean SetUp Time  =0.144297
# Mean Paths per RSE=97.4
# Mean Paths Length per RSE=971.645
# Mean path Width =0.699517
# Mean Special Electric Conductivity =0.0701213
# Mean Special Thermal Conductivity =0.0701213
# Mean Young Modulus =1.31478e+06
# Mean Shear Modulus =778,621
# Mean Poisson Ratio= -0.155697
# ----------------------------------------------------------------------------------------------------
#
# Running 500x500 grid 5 times
# Total time =1.04085sec or 0.0173475min or 0.000289125h
# Finish at Mon Sep 21 09:50:03 2026
# Simulation ended successfully
# Press any key to exit...^C
